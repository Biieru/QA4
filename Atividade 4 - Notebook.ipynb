# %% [markdown]
# # Atividade 5 - Testes Unitários

# %% [markdown]
# ### Atividade 1.
# A partir dos requisitos e casos de uso definidos no exemplo, construa os casos de teste do sistema de calculadora: Cada caso de teste deve conter identificação, descrição, pré-condições, passos, dados de entrada e resultados esperados.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## RESPOSTA (ATIVIDADE 1):
#
# ### Soma com números positivos
#
# Identificação: CT-01
#
# Descrição: Testar soma entre dois números positivos.
#
# Pré-condições: Função somarNum(x, y) disponível.
#
# Passos:
#
#     Informar x = 10
#
#     Informar y = 5
#
#     Executar a soma
#
#     Entrada: (10, 5)
#
# #### Resultado esperado: 15
#
# ---
#
# ### Soma com números negativos
#
# Identificação: CT-02
#
# Descrição: Testar soma envolvendo número negativo.
#
# Pré-condições: Mesma da anterior.
#
# Passos:
#
#     Informar x = -3
#
#     Informar y = 7
#
#     Entrada: (-3, 7)
#
# #### Resultado esperado: 4
#
# ---
#
# ### Subtração simples
#
# Identificação: CT-03
#
# Descrição: Subtração com números positivos.
#
# Pré-condições: Função subtrairNum disponível.
#
# Passos:
#
#     Informar x = 10
#
#     Informar y = 4
#
#     Entrada: (10, 4)
#
# #### Resultado esperado: 6
#
# ---
#
# ### Subtração resultando número negativo
#
# Identificação: CT-04
#
# Descrição: Resultado final negativo.
#
# Passos:
#
#     Informar x = 3
#
#     Informar y = 9
#
#     Entrada: (3, 9)
#
# #### Resultado esperado: -6
#
# ---
#
# ### Multiplicação simples
#
# Identificação: CT-05
#
# Descrição: Multiplicação entre inteiros.
#
# Passos:
#
#     Informar x = 7
#
#     Informar y = 6
#
#     Entrada: (7, 6)
#
# #### Resultado esperado: 42
#
# ---
#
# ### Multiplicação envolvendo zero
#
# Identificação: CT-06
#
# Descrição: Multiplicação por zero.
#
# Passos:
#
#     Informar x = 15
#
#     Informar y = 0
#
#     Entrada: (15, 0)
#
# #### Resultado esperado: 0
#
# ---
#
# ### Divisão simples
#
# Identificação: CT-07
#
# Descrição: Divisão entre inteiros positivos.
#
# Passos:
#
#     Informar x = 20
#
#     Informar y = 4
#
#     Entrada: (20, 4)
#
# #### Resultado esperado: 5
#
# ---
#
# ### Divisão por zero
#
# Identificação: CT-08
#
# Descrição: Deve retornar erro controlado.
#
# Passos:
#
#     Informar x = 10
#
#     Informar y = 0
#
#     Entrada: (10, 0)
#
# #### Resultado esperado: None + mensagem "Erro: Divisão por zero."

# %% [markdown]
# ### Atividade 2
# A partir dos requisitos / casos de testes definidos no exemplo, construa testes unitários para sistema de calculadora:
# Obs.: Use a ferramenta unittest (ou pytest) para construir os testes. Enviar arquivo com a implementação das funções e casos de teste. Não é para desenvolver interface, apenas testar as funções. Use o exemplo como base. Enviar link do repositório ou pasta zipada

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Calculadora.py

def somarNum(x, y):
    return x + y

def subtrairNum(x, y):
    return x - y

def multiplicarNum(x, y):
    return x * y

def dividirNum(x, y):
    if y == 0:
        print("Erro: Divisão por zero.")
        return None
    return x / y

# %%
test_calculadora.py

import unittest
from calculadora import somarNum, subtrairNum, multiplicarNum, dividirNum

class TestCalculadora(unittest.TestCase):

    def test_soma(self):
        self.assertEqual(somarNum(10, 5), 15)
        self.assertEqual(somarNum(-3, 7), 4)

    def test_subtracao(self):
        self.assertEqual(subtrairNum(10, 4), 6)
        self.assertEqual(subtrairNum(3, 9), -6)

    def test_multiplicacao(self):
        self.assertEqual(multiplicarNum(7, 6), 42)
        self.assertEqual(multiplicarNum(15, 0), 0)

    def test_divisao(self):
        self.assertEqual(dividirNum(20, 4), 5)
        # divisão por zero deve retornar None
        self.assertIsNone(dividirNum(10, 0))

if __name__ == "__main__":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 test_calculadora.py
#       3 import unittest
#       4 from calculadora import somarNum, subtrairNum, multiplicarNum, dividirNum
#
# NameError: name 'test_calculadora' is not defined
